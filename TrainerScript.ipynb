# %% [markdown]
# # Installations

# %%
# !pip install -Uq setfit
# !pip install -Uq transformers==4.49
# !pip install -Uq kaleido
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.4 MB/s eta 0:00:00

# %% [markdown]
# # Imports

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import seaborn as sns
from sklearn.preprocessing import OneHotEncoder

import torch
from torch.utils.data import Dataset, DataLoader

from datasets import Dataset as hf_dataset

from setfit import SetFitModel,Trainer,TrainingArguments

from sentence_transformers.losses import CosineSimilarityLoss

import transformers

from sklearn.manifold import TSNE

import plotly.express as px

# %% [markdown]
# # Config

# %%
class config:
  txn_file = "/content/drive/MyDrive/Spend Categorization/my_transactions.csv"
  txn_cat_file = "/content/drive/MyDrive/Spend Categorization/my_transactions_categorized.csv"
  model = 'sentence-transformers/paraphrase-mpnet-base-v2'

# %%
df_txn_cat = pd.read_csv(config.txn_cat_file)

# %%
df_txn_cat.head(4)
# Out:
#                                            Full Text Transaction Type  \
# 0  UPIOUT/451368462558/blinkit.payu@hdfcbank/UP  ...           UPIOUT
# 1  UPIOUT/415140428056/zeptonowcashfree@hdfcb    ...           UPIOUT
# 2  UPIOUT/429504581630/chaayos488077.rzp@rxair   ...           UPIOUT
# 3  UPIOUT/470940782926/Vyapar.170258239279@h     ...           UPIOUT
#
#    Transaction ID                      VPA  Amount  \
# 0    451368462558    blinkit.payu@hdfcbank     228
# 1    415140428056   zeptonowcashfree@hdfcb  325.06
# 2    429504581630  chaayos488077.rzp@rxair      83
# 3    470940782926    Vyapar.170258239279@h     702
#
#                                              Summary   Category
# 0  You have sent 228.00 to blinkit.payu@hdfcbank ...    Grocery
# 1  You have sent 325.06 to zeptonowcashfree@hdfcb...    Grocery
# 2  You have sent 83.00 to chaayos488077.rzp@rxair...       Food
# 3  You have sent 702.00 to Vyapar.170258239279@h ...  Ecommerce

# %%
id2label = {n:k for n,k in enumerate(df_txn_cat['Category'].unique())}
label2id = {k:n for n,k in enumerate(df_txn_cat['Category'].unique())}

# %%
df_txn_cat['label'] = df_txn_cat['Category'].map(label2id)

# %%
enc = OneHotEncoder()
label = enc.fit_transform(df_txn_cat['label'].to_numpy().reshape(-1,1)).toarray()

# %% [markdown]
# # Dataset class

# %%
class TransactionData(Dataset):
    """
    A simple dataset class for PyTorch Lightning that takes lists of texts and labels.
    """

    def __init__(self, texts, labels):
        """
        Args:
            texts (list): List of text strings.
            labels (list): List of corresponding labels (e.g., integers).
        """
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        return {'text': text, 'label': label}

# %%
train_ds = TransactionData(
    df_txn_cat['Summary'].tolist(),
    df_txn_cat['label'].tolist()
)

# %%
train_dl = DataLoader(train_ds, batch_size = 8,shuffle = True)

# %%
# Huggingface datasets

hf_ds = hf_dataset.from_dict({
    'text' : df_txn_cat['Summary'].tolist(),
    'label' : label
})

# %% [markdown]
# # Model

# %%
model = SetFitModel.from_pretrained(config.model, multi_target_strategy="one-vs-rest")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.52k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %% [markdown]
# # Training

# %%
args = TrainingArguments(
    output_dir="models",
    num_epochs=5,
    use_amp=True,
    batch_size=32,
    save_strategy = 'epoch',
    report_to=None,
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
trainer = Trainer(
    model=model,
    args = args,
    train_dataset=hf_ds,
    column_mapping={"text": "text", "label": "label"},

)
# Out:
# Applying column mapping to the training dataset
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Map:   0%|          | 0/73 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num unique pairs = 4496
#   Batch size = 32
#   Num epochs = 5
#     <div>
#
#       <progress value='705' max='705' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [705/705 04:51, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.246100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.166800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.068200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.037600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.022700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.019100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.014700</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.013600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.010200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.013300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.012300</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.011800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.010200</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model.save_pretrained('FinetunedModel/')

# %%
model1 = model.from_pretrained('/content/FinetunedModel',local_files_only= True)

# %%
model.save_pretrained('mymodel/checkpoint')

# %%
# !zip -r /content/FinetunedModel.zip /content/FinetunedModel
# Out:
#   adding: content/FinetunedModel/ (stored 0%)
#   adding: content/FinetunedModel/config_sentence_transformers.json (deflated 34%)
#   adding: content/FinetunedModel/vocab.txt (deflated 53%)
#   adding: content/FinetunedModel/special_tokens_map.json (deflated 85%)
#   adding: content/FinetunedModel/1_Pooling/ (stored 0%)
#   adding: content/FinetunedModel/1_Pooling/config.json (deflated 57%)
#   adding: content/FinetunedModel/README.md (deflated 59%)
#   adding: content/FinetunedModel/model.safetensors (deflated 8%)
#   adding: content/FinetunedModel/model_head.pkl (deflated 9%)
#   adding: content/FinetunedModel/sentence_bert_config.json (deflated 4%)
#   adding: content/FinetunedModel/modules.json (deflated 53%)
#   adding: content/FinetunedModel/tokenizer.json (deflated 71%)
#   adding: content/FinetunedModel/tokenizer_config.json (deflated 75%)
#   adding: content/FinetunedModel/config.json (deflated 47%)
#   adding: content/FinetunedModel/config_setfit.json (deflated 6%)

# %% [markdown]
# # Vizualizations

# %%
model_untrained = SetFitModel.from_pretrained(config.model, multi_target_strategy="one-vs-rest")
# Out:
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
# Trained Embeddings
trained_embeddings = model.encode(df_txn_cat['Summary'].tolist())
tsne = TSNE(n_components=2, random_state=42)
trained_tsne = tsne.fit_transform(trained_embeddings)

# %%
#Untrained Embeddings
untrained_embeddings = model_untrained.encode(df_txn_cat['Summary'].tolist())
tsne = TSNE(n_components=2, random_state=42)
untrained_tsne = tsne.fit_transform(untrained_embeddings)

# %%
fig = px.scatter(x= trained_embeddings[:,0],
                 y= trained_embeddings[:,1],
                 color = df_txn_cat['Category'].tolist(),
                 symbol= df_txn_cat['Category'].tolist(),
                 title = 'Finetuned Model Embeddings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67ab402d-2e62-42cc-9242-b62e6547dcda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67ab402d-2e62-42cc-9242-b62e6547dcda")) {                    Plotly.newPlot(                        "67ab402d-2e62-42cc-9242-b62e6547dcda",                        [{"hovertemplate":"color=Grocery\u003cbr\u003esymbol=Grocery\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grocery, Grocery","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Grocery, Grocery","orientation":"v","showlegend":true,"x":[-0.2117806,-0.12540935,-0.14542128],"xaxis":"x","y":[-0.12994151,-0.18484388,-0.14520417],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Food\u003cbr\u003esymbol=Food\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Food, Food","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Food, Food","orientation":"v","showlegend":true,"x":[-0.014447046,-0.016464783,-0.015664766,-0.016100336,-0.0008498409,-0.024931047,-0.018643096,-0.01875305,-0.015119699,-0.021826101,-0.019538919,-0.01803674,-0.012133663,-0.017290484,-0.020079086],"xaxis":"x","y":[-0.28562278,-0.26031002,-0.26585016,-0.26434484,-0.28505358,-0.2442584,-0.2763824,-0.24649902,-0.24765554,-0.27263477,-0.27023214,-0.2673021,-0.2697432,-0.24769062,-0.2763829],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Ecommerce\u003cbr\u003esymbol=Ecommerce\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecommerce, Ecommerce","marker":{"color":"#00cc96","symbol":"square"},"mode":"markers","name":"Ecommerce, Ecommerce","orientation":"v","showlegend":true,"x":[0.0421047,0.0047138315],"xaxis":"x","y":[-0.3543435,-0.3302264],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Transport\u003cbr\u003esymbol=Transport\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transport, Transport","marker":{"color":"#ab63fa","symbol":"x"},"mode":"markers","name":"Transport, Transport","orientation":"v","showlegend":true,"x":[-0.20779403,-0.12423309,-0.17981413,-0.12283603],"xaxis":"x","y":[0.17602643,0.21890944,0.23244476,0.2079716],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Sports & Fitness\u003cbr\u003esymbol=Sports & Fitness\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sports & Fitness, Sports & Fitness","marker":{"color":"#FFA15A","symbol":"cross"},"mode":"markers","name":"Sports & Fitness, Sports & Fitness","orientation":"v","showlegend":true,"x":[-0.131224,-0.13874786,-0.12323618,-0.12305945],"xaxis":"x","y":[0.002078979,-0.087341964,-0.085446075,-0.09898014],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Subscription\u003cbr\u003esymbol=Subscription\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Subscription, Subscription","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Subscription, Subscription","orientation":"v","showlegend":true,"x":[-0.20324712],"xaxis":"x","y":[0.14555497],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Earnings\u003cbr\u003esymbol=Earnings\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Earnings, Earnings","marker":{"color":"#FF6692","symbol":"diamond"},"mode":"markers","name":"Earnings, Earnings","orientation":"v","showlegend":true,"x":[-0.06708678,-0.06653525,-0.060973395,-0.06223109,-0.053498093,-0.06989112,-0.07004292,-0.06295545,-0.068509564,-0.070939586,-0.05862043,-0.06656982,-0.062346075,-0.062400926,-0.06289401],"xaxis":"x","y":[0.044899467,0.03 ...

# %%
px.scatter(x= untrained_embeddings[:,0],
           y= untrained_embeddings[:,1],
           color = df_txn_cat['Category'].tolist(),
           symbol= df_txn_cat['Category'].tolist())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="787a8968-0b83-4628-8ada-df1eaa4b66a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("787a8968-0b83-4628-8ada-df1eaa4b66a1")) {                    Plotly.newPlot(                        "787a8968-0b83-4628-8ada-df1eaa4b66a1",                        [{"hovertemplate":"color=Grocery\u003cbr\u003esymbol=Grocery\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grocery, Grocery","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Grocery, Grocery","orientation":"v","showlegend":true,"x":[-0.055306595,-0.1583283,-0.088207304],"xaxis":"x","y":[-0.014045461,-0.03404117,0.0995808],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Food\u003cbr\u003esymbol=Food\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Food, Food","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Food, Food","orientation":"v","showlegend":true,"x":[-0.059062477,-0.029747762,-0.05020882,-0.0704201,-0.09351901,-0.10792174,-0.18013123,-0.1683654,-0.06659482,-0.087171145,-0.19066499,-0.078567415,-0.03129386,-0.06677219,-0.043833554],"xaxis":"x","y":[0.028889744,-0.06955019,0.18151772,-0.0052262857,0.26803812,0.018618623,-0.0011940656,0.17255841,0.33273917,0.008738541,0.025822751,0.11096738,0.10719884,0.27950114,-0.026696512],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Ecommerce\u003cbr\u003esymbol=Ecommerce\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecommerce, Ecommerce","marker":{"color":"#00cc96","symbol":"square"},"mode":"markers","name":"Ecommerce, Ecommerce","orientation":"v","showlegend":true,"x":[-0.013039792,-0.12516691],"xaxis":"x","y":[-0.10819526,0.04997721],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Transport\u003cbr\u003esymbol=Transport\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transport, Transport","marker":{"color":"#ab63fa","symbol":"x"},"mode":"markers","name":"Transport, Transport","orientation":"v","showlegend":true,"x":[-0.07607802,-0.118651524,-0.08184329,-0.1389105],"xaxis":"x","y":[-0.11157584,0.21161215,0.16541414,0.18453068],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Sports & Fitness\u003cbr\u003esymbol=Sports & Fitness\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sports & Fitness, Sports & Fitness","marker":{"color":"#FFA15A","symbol":"cross"},"mode":"markers","name":"Sports & Fitness, Sports & Fitness","orientation":"v","showlegend":true,"x":[-0.14760174,-0.13818224,-0.13662617,-0.079899415],"xaxis":"x","y":[0.22756469,0.06165762,0.094351634,0.00044749456],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Subscription\u003cbr\u003esymbol=Subscription\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Subscription, Subscription","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Subscription, Subscription","orientation":"v","showlegend":true,"x":[-0.16474396],"xaxis":"x","y":[0.11198019],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=Earnings\u003cbr\u003esymbol=Earnings\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Earnings, Earnings","marker":{"color":"#FF6692","symbol":"diamond"},"mode":"markers","name":"Earnings, Earnings","orientation":"v","showlegend":true,"x":[-0.09794312,-0.087315306,-0.09606902,-0.07742917,-0.028596666,-0.10745612,-0.10505598,-0.05532203,-0.08126276,-0.116279356,-0.020729693,-0.03989134,-0.018058125,-0.13932386,-0.103522696],"xaxis":"x","y":[-0.093387835,-0.0 ...

# %%
px.scatter().to_

# %% [markdown]
# # Inference

# %%
# !unzip /content/FinetunedModel.zip

# %%
model = SetFitModel.from_pretrained('/content/FinetunedModel')

# %%
def extraction(fullText: str) -> str:
  trans_type = fullText.split('/')[0]
  transaction_id = fullText.split('/')[1]
  vpa = fullText.split('/')[2].split(' ')[0]
  amount = fullText.split('/')[3].split(' ')[-1]

  return trans_type,vpa,amount

def generate_summary(transaction_type: str,
                     VPA : str,
                     amount : str
                     ) -> str:

  if transaction_type.lower() == 'UPIOUT'.lower():
    summary = f"You have sent {amount.strip()} to {VPA.strip()} via UPI"

  elif transaction_type.lower() == 'UPI IN'.lower():
    summary = f"You have received {amount.strip()} from {VPA.strip()} via UPI"

  elif transaction_type.lower() == 'CHRG'.lower():
    summary = f"You have been charged {amount.strip()} to {VPA.strip()}"

  else:
    summary = 'Null'

  return summary

# %%
def pred(narration) -> str:
  transaction_type,vpa,amount = extraction(narration)
  summary = generate_summary(transaction_type,vpa,amount)
  print(f'{summary}')

  preds = model([summary])
  preds = id2label[int(np.argmax(preds))]
  return preds

# %%
narration = 'UPIOUT/509042621775/wellnessquotien833.rzp@i/7298    260.00'
pred(narration)
# Out:
# You have sent 260.00 to wellnessquotien833.rzp@i via UPI
# 'Sports & Fitness'

# %%
narration = 'UPIOUT/409826621840/zomatoonlineorder.rzp@ic/                   75.00'
pred(narration)
# Out:
# You have sent 75.00 to zomatoonlineorder.rzp@ic via UPI
# 'Food'

# %%
narration = 'UPIOUT/411144932833/BURGERKINGINDIA@ybl/Pa                  178.92'
pred(narration)
# Out:
# You have sent 178.92 to BURGERKINGINDIA@ybl via UPI
# 'Food'
